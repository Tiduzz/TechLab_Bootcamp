# %% [markdown]
# <h1><center>DETECÇÃO FACIAL TECNORIA</center></h1>

# %%
#!pip install imageio-ffmpeg
#!pip install opencv-contrib-python

# %%
# !ls /usr/local/share/opencv4/haarcascades
# Out:
# haarcascade_eye.xml
# haarcascade_eye_tree_eyeglasses.xml
# haarcascade_frontalcatface.xml
# haarcascade_frontalcatface_extended.xml
# haarcascade_frontalface_alt.xml
# haarcascade_frontalface_alt2.xml
# haarcascade_frontalface_alt_tree.xml
# haarcascade_frontalface_default.xml
# haarcascade_fullbody.xml
# haarcascade_lefteye_2splits.xml
# haarcascade_licence_plate_rus_16stages.xml
# haarcascade_lowerbody.xml
# haarcascade_profileface.xml
# haarcascade_righteye_2splits.xml
# haarcascade_russian_plate_number.xml
# haarcascade_smile.xml
# haarcascade_upperbody.xml

# %%
import io
import PIL.Image
import IPython
import cv2
import os
import imageio
import numpy as np
import math
from matplotlib import pyplot as plt
from IPython.display import Image, display, clear_output

# %% [markdown]
# ## 1. Detecção em Imagens

# %%
# Load the cascade
classifier_folder = '/usr/local/share/opencv4/haarcascades/'
classifier_path = os.path.join(classifier_folder, 'haarcascade_frontalface_default.xml')
classifier_path2 = os.path.join(classifier_folder, 'haarcascade_eye.xml')
classifier_path3 = os.path.join(classifier_folder, 'haarcascade_smile.xml')
face_cascade = cv2.CascadeClassifier(classifier_path)
eye_cascade = cv2.CascadeClassifier(classifier_path2)
smile_cascade = cv2.CascadeClassifier(classifier_path3)
print(eye_cascade.empty())
# Out:
# False

# %%
# function for rendering an array as an image
def showarray(a, fmt='jpeg'):
    f = io.BytesIO()
    PIL.Image.fromarray(a).save(f, fmt)
    display(Image(data=f.getvalue()))

# %% [markdown]
# ## 2. Detecção de Proximidade

# %%
# Read the input image
img2 = cv2.imread("friends2.png")

# %%
# Convert into grayscale
gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

# %%
faces = face_cascade.detectMultiScale(gray2, 1.3, 5)

# %%
# RGB color
img_rgb2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
showarray(img_rgb2)

# %%
# Detect lines and columns
linhas = len(faces)
try:
    colunas = len(faces[0])
except:
    colunas = 0

# %%
# Draw rectangle around the faces
for (x,y,w,h) in faces:
    img2 = cv2.rectangle(img_rgb2, (x, y), (x+w, y+h), (255, 0, 0), 2)
    
    #Fazer circulo no meio do retangulo
    img2 = cv2.circle(img2, (x+w//2, y+h//2), 5, (255,0 ,0), -1)
    
    #Função para traçar linhas
    if linhas>1 and colunas>=1: 
        for x in range(linhas):
            for y in range(linhas):
                dist = (((faces[x][0]+(faces[x][2]//2))-(faces[y][0]+(faces[y][2]//2)))**2 + (((faces[x][1]+(faces[x][3]//2))-(faces[y][1]+(faces[y][3]//2))))**2)
                b = math.sqrt(dist)
                if b<100:
                    img2 = cv2.line(img_rgb2, (faces[x][0]+faces[x][2]//2,faces[x][1]+faces[x][3]//2), (faces[y][0]+faces[y][2]//2, faces[y][1]+faces[y][3]//2), (255, 255, 0), 2) 
showarray(img2)

# %% [markdown]
# ## 3. Detecção em Vídeo

# %%
import io
import PIL.Image
import IPython
import cv2
import os
import imageio
import numpy as np
import math
from matplotlib import pyplot as plt
from IPython.display import Image, display, clear_output

# %%
# Load the cascade
classifier_folder = '/usr/local/share/opencv4/haarcascades/'
classifier_path = os.path.join(classifier_folder, 'haarcascade_frontalface_default.xml')
classifier_path2 = os.path.join(classifier_folder, 'haarcascade_eye.xml')
classifier_path3 = os.path.join(classifier_folder, 'haarcascade_smile.xml')
face_cascade = cv2.CascadeClassifier(classifier_path)
eye_cascade = cv2.CascadeClassifier(classifier_path2)
smile_cascade = cv2.CascadeClassifier(classifier_path3)
print(eye_cascade.empty())
# Out:
# False

# %%
# function for rendering an array as an image
def showarray(a, fmt='jpeg'):
    f = io.BytesIO()
    PIL.Image.fromarray(a).save(f, fmt)
    display(Image(data=f.getvalue()))

# %%
# !file mask.mp4
# Out:
# mask.mp4: ISO Media, MP4 v2 [ISO 14496-14]

# %%
cap = cv2.VideoCapture('mask.mp4')
cap.isOpened()
# Out:
# True

# %%
i=1

while(cap.isOpened()):  
    ret, frame = cap.read()  
    
    if ret == False:
        break 
  
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY ) 
    faces = face_cascade.detectMultiScale(gray,1.3, 4)
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    for (x, y ,w ,h) in faces:
        cv2.rectangle(frame ,(x,y),(x+w , y+h), (255,0,0)  ,3)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = frame[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray, 1.3, 4)
        smile = smile_cascade.detectMultiScale(roi_gray, 1.1, 99)
        for (ex,ey,ew,eh) in eyes:
            cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0), 3)
        for (sx,sy,sw,sh) in smile:
            cv2.rectangle(roi_color,(sx,sy),(sx+sw,sy+sh),(0,0,0), 3)
        
  
    # write the frame  
    if i%350 == 0:
        roi_filtro = frame[y:y+h, x:x+w]
        blur = cv2.GaussianBlur(roi_filtro,(27, 27), 27)
        frame[y:y+h, x:x+w] = blur
        cv2.imwrite('teste_video'+str(i)+'.jpg',frame)
    i+=1  
  
    showarray(frame)    
    clear_output(wait = True)


# Release everything if job is finished  
cap.release()
cv2.destroyAllWindows()

# %%
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model
import numpy as np
import argparse
import cv2
import os
import io
import imageio
import PIL.Image
import io
import PIL.Image
import IPython
import cv2
import os
import imageio
import numpy as np
import math
from matplotlib import pyplot as plt
from IPython.display import Image, display, clear_output
import time
from datetime import datetime
import getpass


# function for rendering an array as an image
def showarray(a, fmt='jpeg'):
    f = io.BytesIO()
    PIL.Image.fromarray(a).save(f, fmt)
    display(Image(data=f.getvalue()))

# %%
# Load the cascade
classifier_folder = '/usr/local/share/opencv4/haarcascades/'

classifier_path2 = os.path.join(classifier_folder, 'haarcascade_eye.xml')
classifier_path3 = os.path.join(classifier_folder, 'haarcascade_smile.xml')

eye_cascade = cv2.CascadeClassifier(classifier_path2)
smile_cascade = cv2.CascadeClassifier(classifier_path3)
    
print(eye_cascade.empty())
print(smile_cascade.empty())
# Out:
# False
# False

# %%
def detect_faces(image_gray, scale, neighbors):
    classifier = 'haarcascade_frontalface_default.xml'
    classifier_path = os.path.join('/usr/local/share/opencv4/haarcascades/', classifier)

    face_cascade = cv2.CascadeClassifier(classifier_path)

    if not face_cascade.empty():
        faces = face_cascade.detectMultiScale(image_gray, scale, neighbors)
        
        return faces
    return []

#Video selecionado
cap2 = cv2.VideoCapture('video5.avi')

#Local que vai armazenar as imagens
#imgFolder = "/home" + getpass.getuser() + "/documents"
frameRate = cap2.get(5) #frame rate

cur_time = time.time()  # Get current time

# start_time_24h measures 24 hours
start_time_24h = cur_time

# start_time_1min measures 1 minute
start_time_1min = cur_time - 59  # Subtract 59 seconds for start grabbing first frame after one second
                                 #(instead of waiting a minute for the first frame).

#Modelo Pré Treinado
model = load_model('mask_detector.model')

#Contador de frames
j=1


while(cap2.isOpened()):
    frameId = cap2.get(1)  # current frame number
    ret, frame = cap2.read()  
        
    if ret == False:
        break
        
    cur_time = time.time()  # Get current time
    elapsed_time_1min = cur_time - start_time_1min  # Time elapsed from previous image saving.

  
    frame_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY ) 
    faces = detect_faces(frame_gray, 1.3, 6)
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    #print ("[INFO] Foi encontrado {0} Rostos.".format(len(faces)))
    #if elapsed_time_1min >= 60:
    for i in range(len(faces)):
            x, y, w, h = faces[i]
            image_rect = cv2.rectangle(frame, (x,y), (x+w,y+h), (255,0,0), 2)
            #eyes = eye_cascade.detectMultiScale(frame_gray, 1.3, 4)
            smile = smile_cascade.detectMultiScale(frame_gray, 1.1, 99)

            face = frame[y:y+h, x:x+w]
            face = cv2.resize(face, (224, 224))
            face = preprocess_input(face)
            face = np.expand_dims(face, axis=0)
            
            #roi_filtro = frame[y:y+h, x:x+w]
            #aq = cv2.GaussianBlur(roi_filtro,(27, 27), 27)
            #frame[y:y+h, x:x+w] = aq

            (mask, no_mask) = model.predict(face)[0]
           
            #determine the class label and color we'll use to draw the bounding box and text
            label = "Mascara" if mask > no_mask else "Sem Mascara"
            color = (0, 255, 0) if label == "Mascara" else (255, 0, 0)
            
            #cv2.imwrite(str(w) + str(h) + '_faces.jpg', face)

            #include the probability in the label
            #label = "{}: {:.2f}%".format(label, max(mask, no_mask)*100)
            
            #display the label and bounding box rectanble on the output frame
            cv2.putText(frame, label, (x, y - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, color, 3)
            cv2.rectangle(frame, (x, y), (x+w, y+h), color, 2)
        
            
            #if mask >= 0.90: 
                #image_rect = cv2.rectangle(frame, (x,y), (x+w,y+h), (0,255,0), 2)
                #label = "Mascara"
                #color = (0, 255, 0)
                #start_time_1min = cur_time
                #filename = "face_masked_" + str(datetime.now().strftime("%d-%m-%Y_%I-%M-%S_%p"))  + ".jpg"
                #cv2.imwrite(filename, frame)
                #cv2.imwrite(str(w) + str(h) + '_faces_masked.jpg', face)
                #print ("[INFO] Foi encontrado {0} Rostos com Máscara.".format(len(faces)))
            #else:
                #image_rect = cv2.rectangle(frame, (x,y), (x+w,y+h), (255,0,0), 2)
                #label = "Sem Mascara"
                #color = (255, 0, 0)
                #start_time_1min = cur_time
                #filename = "face_unmasked_" + str(datetime.now().strftime("%d-%m-%Y_%I-%M-%S_%p"))  + ".jpg"
                #cv2.imwrite(filename, frame)
                #cv2.imwrite(str(w) + str(h) + '_face_unmasked.jpg', frame)
                #print ("[INFO] Foi encontrado {0} Rostos sem Máscara.".format(len(faces)))
        
            
    #status = cv2.imwrite('faces_detected.jpg', frame)
    #print ("[INFO] Imagens faces_detected.jpg salvas no sistema: ", status)
  
    # write the frame  
    #if j%50 == 0:
    #    roi_filtro = frame[y:y+h, x:x+w]
    #    aq = cv2.GaussianBlur(roi_filtro,(27, 27), 27)
    #    frame[y:y+h, x:x+w] = aq
    #    cv2.imwrite('teste_video'+str(j)+'.jpg',frame)
    #j+=1 
    
            # write the frame  
            if elapsed_time_1min >= 60:
                roi_filtro = frame[y:y+h, x:x+w]
                aq = cv2.GaussianBlur(roi_filtro,(27, 27), 27)
                frame[y:y+h, x:x+w] = aq
                start_time_1min = cur_time
                if mask >= 0.80:
                    filename = "face_masked_" + str(datetime.now().strftime("%d-%m-%Y_%I-%M-%S_%p"))  + ".jpg"
                    cv2.imwrite(filename, frame)
                else:
                    filename = "face_unmasked_" + str(datetime.now().strftime("%d-%m-%Y_%I-%M-%S_%p"))  + ".jpg"
                    cv2.imwrite(filename, frame)
            
            elapsed_time_24h = time.time() - start_time_24h

            #Break loop after 24*60*60 seconds
            if elapsed_time_24h > 24*60*60:
                break
    
  
    showarray(frame_rgb)
    clear_output(wait = True)


# Release everything if job is finished  
cap2.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## 4. Pré processamento de Imagens

# %%
import cv2
import numpy as np
from scipy.spatial import distance as dist
import os

# %%
# Load the cascade
classifier_folder = '/usr/local/share/opencv4/haarcascades/'
classifier_path = os.path.join(classifier_folder, 'haarcascade_frontalface_default.xml')

face_model = cv2.CascadeClassifier(classifier_path)

print(face_cascade.empty())

#Video selecionado
cap = cv2.VideoCapture('video5.avi')
# Out:
# False

# %%
status , photo = cap.read()
showarray(photo)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-4e9e6e4d8bdf> in <module>
#       1 status , photo = cap.read()
# ----> 2 showarray(photo)
#       3 cv2.waitKey()
#       4 cv2.destroyAllWindows()
#
# <ipython-input-3-b97020ef0b61> in showarray(a, fmt)
#       2 def showarray(a, fmt='jpeg'):
#       3     f = io.BytesIO()
# ----> 4     PIL.Image.fromarray(a).save(f, fmt)
#       5     display(Image(data=f.getvalue()))
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in fromarray(obj, mode)
#    2737     .. versionadded:: 1.1.6
#    2738     """
# -> 2739     arr = obj.__array_interface__
#    2740     shape = arr["shape"]
#    2741     ndim = len(shape)
#
# AttributeError: 'NoneType' object has no attribute '__array_interface__'

# %%
while True:
    status , photo = cap.read() 
    face_cor = face_model.detectMultiScale(photo)
    l = len(face_cor)
    photo = cv2.putText(photo, str(len(face_cor))+" Face", (50, 50), cv2.FONT_HERSHEY_SIMPLEX,  
                   1, (255, 0, 0) , 2, cv2.LINE_AA) 
    stack_x = [] 
    stack_y = []
    stack_x_print = [] 
    stack_y_print = []
    global D
    
    if len(face_cor) == 0:
        pass
    
    else:
        for i in range(0,len(face_cor)):
            x1 = face_cor[i][0]
            y1 = face_cor[i][1]
            x2 = face_cor[i][0] + face_cor[i][2]
            y2 = face_cor[i][1] + face_cor[i][3]
            
             
            mid_x = int((x1+x2)/2)
            mid_y = int((y1+y2)/2)
            stack_x.append(mid_x)
            stack_y.append(mid_y)
            stack_x_print.append(mid_x)
            stack_y_print.append(mid_y)
            
            photo = cv2.circle(photo, (mid_x, mid_y), 3 , [255,0,0] , -1) 
            photo = cv2.rectangle(photo , (x1, y1) , (x2,y2) , [0,255,0] , 2)
        
        if len(face_cor) == 2:
            D = int(dist.euclidean((stack_x.pop(), stack_y.pop()), (stack_x.pop(), stack_y.pop())))
            photo = cv2.line(photo, (stack_x_print.pop(), stack_y_print.pop()), (stack_x_print.pop(), stack_y_print.pop()), [0,0,255], 2)
        else:
            D = 0
        
        if D<250 and D!=0:
            photo = cv2.putText(photo, "!!MOVE AWAY!!", (120, 100), cv2.FONT_HERSHEY_SIMPLEX,2, [0,0,255] , 4)
            
        photo = cv2.putText(photo, str(D/10) + " cm", (300, 50), cv2.FONT_HERSHEY_SIMPLEX,  
                   1, (255, 0, 0) , 2, cv2.LINE_AA)
        
        showarray(photo)
        clear_output(wait = True)


# Release everything if job is finished  
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-e175b3f6c062> in <module>
#       4     l = len(face_cor)
#       5     photo = cv2.putText(photo, str(len(face_cor))+" Face", (50, 50), cv2.FONT_HERSHEY_SIMPLEX,
# ----> 6                    1, (255, 0, 0) , 2, cv2.LINE_AA)
#       7     stack_x = []
#       8     stack_y = []
#
# KeyboardInterrupt:
